# %%
## 클래스를 선언
class Class_1():
    def func_1(self):
        print("Class_1 Call")

# %%
## 클래스 생성
a = Class_1()
print(a)
# Out:
# <__main__.Class_1 object at 0x000001B26EF314D0>

# %%
a.func_1()
# Out:
# Class_1 Call

# %%
## 클래스 선언 
## 생성자 함수를 입력
class Class_2():
    def __init__(self, input_a, input_b):
        self.a = input_a
        self.b = input_b

# %%
b = Class_2(5, 1)

# %%
c= Class_2("test", "test2")

# %%
print(b.a)
print(c.a)
# Out:
# 5
# test

# %%
class Class_3():
    def add(self):
        self.result = self.x + self.y
        return self.result
    def subtract(self):
        self.result = self.x - self.y
        return self.result
    def __init__(self, input_x, input_y):
        self.x = input_x
        self.y = input_y

# %%
class_a = Class_3(10, 2)
class_b = Class_3(50, 10)

# %%
print(class_a.add())
print(class_b.add())
# Out:
# 12
# 60

# %%
print(class_a.subtract())
print(class_b.subtract())
# Out:
# 8
# 40

# %%
class Class_4():
    _list = []

    def __init__(self, input_name):
        self.name = input_name
    
    def add_list(self, input_phone):
        self._list.append(input_phone)

# %%
test = Class_4("test")
test2 = Class_4("test2")

# %%
test._list
# Out:
# []

# %%
test.add_list("01012345678")

# %%
print(test._list)
# Out:
# ['01012345678']

# %%
test2.add_list("01078945623")

# %%
print(test2._list)
# Out:
# ['01012345678', '01078945623']

# %%
import mod1
## 모듈 리로드
import imp
imp.reload(mod1)
# Out:
# <module 'mod1' from 'c:\\Users\\ezen\\Documents\\GitHub\\ezen-python\\230204\\mod1.py'>

# %%
print(mod1.x)
# Out:
# module test

# %%
func_result = mod1.func_1(5, 2)
print(func_result)
# Out:
# 7

# %%
class_result = mod1.Class_1("Class test")

# %%
print(class_result)
# Out:
# <mod1.Class_1 object at 0x0000026334F78D90>

# %%
print(class_result.view_data())
# Out:
# Class에서 입력받은 data의 값은 Class test이다

# %%
import mod2

# %%
print(mod2.x)
# Out:
# module test

# %%
print(mod2.func_1(5,2))
# Out:
# 3
